# %%
import pandas as pd

# %%
# Read in csv files
terminations = pd.read_csv("MembershipTerminations.csv")
terminations = terminations[terminations["TerminationReason"] == "membership_cancelled"]
usage_types = pd.read_csv("UsageTypes.csv")
visits_per_month = pd.read_csv("VisitsPerMonth.csv")

# %%
df = pd.merge(terminations, usage_types, on = "User_id", how = "inner")
df = pd.merge(df, visits_per_month, on = ["Id", "User_id"], how = "inner")
undisclosed_cols = ["Gender", "Ethnicity", "IsDisabled", "Persona", "output_area_classification_supergroup"]
df[undisclosed_cols] = df[undisclosed_cols].fillna("Not Given")
df["DiscountType"] = df["DiscountType"].fillna("No Discount")
df["output_area_classification_supergroup"] = df["output_area_classification_supergroup"].replace({"(pseudo) CI, IoM": "Not Given"})

# Gender mapping
gender_map = {
    'Male': 'Male',
    'M': 'Male',
    'Female': 'Female',
    'F': 'Female',
    'Non Binary': 'Non Binary',
    'Other': 'Non Binary',
    
    'Prefer Not To Say': 'Not Given',
    'Unknown': 'Not Given',
    'Not Given': 'Not Given'
}

# Apply mapping, default to 'not given' if value is not in the map
df['Gender'] = df['Gender'].map(gender_map).fillna('Not Given')

# Filter age to between 0 and 100
df = df[(df['MemberAge'] >= 0) & (df['MemberAge'] <= 100)]

# Filter VisitsPerMonth to between 0 and 50
df = df[(df['VisitsPerMonth'] >= 0) & (df['VisitsPerMonth'] <= 50)]

df = df.dropna()

# %%
for col in df.columns:
    print(f"{col}: {df[col].unique()}")
# Out:
# Id: [    512    3343    4456 ... 4208623 4220020 4294591]
# User_id: [    910    3782    4913 ... 6565947 6420184 6438378]
# MemberAge: [43. 33. 42. 30. 75. 76. 62. 52. 51. 67. 41. 84. 20. 57. 45. 55. 47. 71.
#  63. 68. 39. 38. 28. 73. 31. 59. 61. 26. 70. 60. 22. 34. 23. 25. 18. 24.
#  54. 50. 36. 48. 64. 37. 58. 65. 35. 27. 53. 90. 49. 46. 77. 44. 29. 56.
#  32. 40. 78. 21. 79. 81. 74. 66. 72. 19. 69.  3. 80. 17. 16. 82. 14. 89.
#  91. 11. 83. 13. 86. 12. 15. 87. 85.  6.  5.  7. 10. 94.  4.  8. 88. 92.
#   9. 93.  2.  1. 95. 96. 98. 97.  0.]
# Gender: ['Male' 'Female' 'Not Given' 'Non Binary']
# Ethnicity: ['White' 'Not Given' 'Mixed or Multiple ethnic groups'
#  'Black, Black British, Black Welsh, Caribbean or African'
#  'Asian, Asian British or Asian Welsh' 'Other ethnic group']
# IsDisabled: ['No' 'Not Given' 'Yes']
# Membership: ['Better Health Centre' 'Better Swim' 'Better Health Partnership'
#  'Better Health UK' 'Better Health Corporate' 'Better Student'
#  'Better Health Centre Junior' 'Better Racquets' 'Better Health UK Junior'
#  'Better HF GP Referral' 'Better Health Partnership Junior'
#  'Better Sports Junior' 'Better Sports Adult' 'Better Swim Senior'
#  'Better Health Region' 'Better Golf' 'Better Ice' 'Better Tennis'
#  'Better Spa' 'Livery' 'Better Health UK Adult Pay & Play'
#  'Better Health UK Junior Pay & Play' 'Better Health UK Pilot'
#  'Better GP Referral']
# MembershipType: ['Better Health Centre Bolt On' 'Better Health Centre Senior G&C'
#  'Better Health Centre Saver' 'Better Health Centre'
#  'Better Health Centre - G&C' 'Better Swim Centre'
#  'Better Swim Partnership' 'Better Health Partnership Senior 66+ Off Peak'
#  'Better Health UK Staff' 'Better Health Corporate Partnership'
#  'Better Health Partnership Saver'
#  'Better Health Corporate Student A List' 'Better Health UK Inclusive'
#  'Better Health Partnership' 'Better Student UK'
#  'Better Health Centre Junior Plus Racquets' 'Better Racquets'
#  'Better Swim' 'Better Health Corporate Centre A List' 'Better Health UK'
#  'Better Health UK Plus Spa' 'Better Swim Premium'
#  'Better Health UK Society Staff' 'Better Health Partnership Senior'
#  'Better Swim Triathlon' 'Better Health Corporate UK'
#  'Better Health UK Joint Res' 'Better Health Partnership Senior 60+'
#  'Better Health Centre - G,C&HS' 'Better Health Partnership Tri Borough'
#  'Better Health Corporate NHS' 'Better Health Centre - G,S&C'
#  'Better Health Corporate UK Plus Spa'
#  'Better Health Corporate UK Invoiced' 'GLL Sports Foundation Adult'
#  'Better Student Non Res' 'Better Health Corporate Centre'
#  'Better Student Plus Spa' 'Better Health Corporate Partnership Plus Spa'
#  'GLL Sports Foundation Junior' 'Better Student Centre'
#  'Better Health UK Society Staff Plus 1'
#  'Lee Valley Athletics Centre Membership - Adult' 'Better Health UK Joint'
#  'Better Health Partnership Res' 'Better HF Healthy Living 2 Years'
#  'Better Health Corporate Council' 'Better Health Centre Junior'
#  'Better Health Centre Senior' 'Better Health Centre Senior - G,C&HS'
#  'Better Health Partnership Junior' 'Better Health Centre Multi GX'
#  'Better Health Centre Promo' 'Better Health Centre Multi AZ'
#  'Better Student Res' 'Better Health Partnership Senior 66+'
#  'Better Swim and Aqua' 'Better Health Partnership Junior Plus Racquets'
#  'Better HF GP Referral Year 3' 'Better Student Partnership'
#  'Better HF GP Referral Year 1' 'Better Health Centre Saver - G,S&C'
#  'Better Health Partnership Concessionary'
#  'Better Health Partnership Plus Racquets'
#  'Better Health Centre Senior - G,S&C' 'Better Health Partnership Joint'
#  'Better Health Partnership Plus Spa'
#  'Better Health Centre Saver - G,C&HS' 'Better Sports Junior Athletics'
#  'Better Health Partnership Senior 55+' 'Better Health Centre Multi BA'
#  'Better Sports Adult Athletics Student'
#  'Better Health Partnership Inclusive' 'Better HF GP Referral Year 2'
#  'Better Health Centre Saver G&C'
#  'Better Health Partnership Senior 55+ Off Peak'
#  'Better Sports Adult Athletics' 'Better HF GP Referral Year 4'
#  'Better Health Partnership Senior 50+'
#  'Better Health Centre Bolt On Racquets' 'Better Student Partnership CA'
#  'Better Health Corporate Partnership Plus Racquets'
#  'Better Swim & Health Suite' 'Better Health Centre - Gym only'
#  'Better Health Partnership Dual Senior' 'Better Health Centre - S&C'
#  'Better Swim Region' 'Better Student Region Plus Racquets'
#  'Better Health Corporate Region' 'Better Health Centre Gym and Swim CG'
#  'Better Health Partnership Staff' 'Better Health Centre - G&S'
#  'Better Swim Senior' 'Better Health Region Plus Racquets'
#  'Better Health Corporate Partnership Plus Climb'
#  'Better Health Partnership Plus Climb'
#  'Better Health Corporate Centre NHS'
#  'Better Health Partnership Senior Plus Racquets'
#  'Better Golf Intermediate' 'Better Ice Student' 'Better Ice Adult'
#  'Better Ice Adult Training' 'Better HF Health GSTT'
#  'Better Tennis Adult FY' 'Better Health Partnership Corporate Invoiced'
#  'Better Health Partnership Ice' 'Better Tennis Junior FY'
#  'Better Health Partnership Junior Plus Ice'
#  'Better Health Partnership Non Res' 'Better Ice Junior'
#  'Better Health Partnership Res Joint' 'Better Health Centre Res'
#  'Better Health Partnership Plus Toning Suite'
#  'Better Health Partnership Junior Plus Courses'
#  'Better Health Partnership Senior Plus Toning Suite'
#  'Better Health Partnership Plus Lido'
#  'Better Health Partnership Senior Joint' 'Better Ice Junior Patch'
#  'Better Health Region' 'Gym Only'
#  'Better Health Partnership Junior Concessionary'
#  'Better Health Partnership Junior GD'
#  'Better Health Partnership Junior Plus Lido' 'Better Student DA'
#  'Better Health Corporate Junior' 'Better Health Region Student'
#  'Better Health Partnership Senior 50+ Off Peak'
#  'Better Health UK Plus Ice'
#  'Better Health Partnership Concessionary anytime'
#  'Better Health Corporate Region Invoiced'
#  'Better Health Partnership Res DA' 'Better Health Centre Saver - G&S'
#  'Better Health Corp Student Grand Felda Invoiced'
#  'Better Health Partnership Plus Ice' 'Better Health Partnership PT'
#  'Better Health UK Res' 'Better Health UK Non Res'
#  'Better Health UK Joint Non Res' 'Better HF GP Referral Funded'
#  'Better Health Partnership Joint Plus Spa'
#  'Better Health Corporate Centre - G&C'
#  'Better Health Region Senior Plus Racquets'
#  'Be Active Partnership Concessionary'
#  'Better Health Corporate Centre Invoiced'
#  'Better Health Partnership Plus Spa & Racquets'
#  'Better Health Centre Senior - Gym only' 'Better Health Centre - G,S&HS'
#  'Better HF Health 3 months'
#  'Better Health Partnership Concessionary Care Leaver'
#  'Better Health Partnership LAC Funded' 'Better Health Partnership Funded'
#  'Lee Valley Athletics Centre Membership - Junior'
#  'Better Health Centre Non Res'
#  'Better Health Corp Student Felda House Invoiced'
#  'Better Health Partnership Senior 60+ Off Peak'
#  'Better Health Corporate Centre High Street'
#  'Better HF Healthy Living NHS 2 Years' 'Better Health UK PT'
#  'Better Swim Corporate Invoiced' 'Better Health Centre Saver - G,S&HS'
#  'Better Health Centre Senior - G&S' 'Better Ice Adult Patch'
#  'Better Health UK Plus Tennis' 'Better HF GP Referral Plus Year 1'
#  'Better Spa Thermal' 'Better Health Centre Plus Racquets NN04'
#  'Better Health Corporate Key Partners'
#  'Better Health UK Funded Refugee Off Peak'
#  'Better Health Student Partnership 9 months CA'
#  'Better Health UK LLDC Staff'
#  'Better Health Partnership Concessionary Joint'
#  'Better Health Corporate Partnership Senior Joint'
#  'Better Health UK Junior Society Staff Plus 1'
#  'Better Health Corporate Partnership Plus MA02'
#  'Better Health UK Junior Funded Refugee'
#  'Better Student Partnership Promo' 'Better Health Student 9 Months CK02'
#  'Better Tennis Senior FY' 'Better HF GP Referral Plus Year 2'
#  'Better Health Partnership Junior Concessionary Plus Racquets'
#  'Better Golf' 'Better Health UK Joint Plus Spa'
#  'Better Health Partnership Non Res DA'
#  'Better Health Partnership Junior DA' 'Part Livery'
#  'Part Livery & Muck Out'
#  'Better Health Partnership Concessionary LAC Foster'
#  'Better Health Centre PT Plus LVAC' 'Livery Share 1/2'
#  'Better Health Centre Wellbeing Suite'
#  'Better Health Partnership Plus Tennis' 'Better Health Centre Multi GD02'
#  'Better Health Centre Plus Racquets'
#  'Better Health Student 6 Months CK02' 'Better Health Partnership DA'
#  'Better Health UK Funded Refugee' 'Better Golf & Gym'
#  'Better Health Centre Senior - G,S&HS' 'Better Swim Joint'
#  'Better Health Partnership Saver Joint'
#  'Better Health Partnership Concessionary DA' 'Better Squash'
#  'Better Flex Adult' 'GLL Sports Foundation Adult (NE)'
#  'Better Health Community Network (Partnership)' 'Better Health UK Carers'
#  'Better Health Community Network (Centre)'
#  'Lee Valley Ice Centre Health & Fitness'
#  'Lee Valley Ice Centre Ice Skating Adult'
#  'Better Health Community Network UK'
#  'Better HF Healthy Living 2 Years offline'
#  'Better Health Centre Senior - S&C' 'Better Tennis Outdoor FY'
#  'Lee Valley Ice Training Junior' 'GLL Sports Foundation Junior (NE)'
#  'Better Flex Adult Concessionary' 'Better Student UK Elevate'
#  'Better Health UK Junior Inclusive'
#  'Better Health Corporate UK Plus Spa Invoiced'
#  'Lee Valley Partnership Health & Fitness Junior'
#  'Lee Valley Partnership Health & Fitness Student'
#  'Better Health Student Funded 8 weeks' 'Lee Valley Ice Training'
#  'Better Health Corporate Herts Constabulary' 'Better Flex Junior'
#  'Lee Valley Partnership Health & Fitness Concessionary'
#  'Lee Valley Ice Centre Ice Skating Junior' 'Better HF GP Third Party'
#  'Better HF GP Get Active Programme'
#  'Better Health Centre Concession off peak'
#  'Better Health Partnership Junior Inclusive' 'Better Student Centre CK'
#  'Better Health Corporate UK offline'
#  'Lee Valley Partnership Health & Fitness'
#  'Better Health UK + Elevate + Spa'
#  'Better Health Partnership Concession anytime plus racquets'
#  'Better Health Partnership Senior 50+ plus racquets'
#  'Better Health Partnership Junior LAC Funded'
#  'Better Health Centre PT LVAC'
#  'Better Health Corporate Centre Off Peak Invoiced'
#  'Better HF Health Junior 1 months'
#  'Better Health Corporate Centre Invoiced Lee Valley'
#  'Better Health Corporate Partnership DA'
#  'Better Health Corporate Partnership offline'
#  'Better Health Corporate Partnership Junior Invoiced'
#  'Lee Valley Ice Centre Membership - Junior' 'Better College Staff'
#  'Better HF Health 1 month' 'Lee Valley Ice Training Student'
#  'Better Health UK Community Funded 3 months'
#  'Better Health Partnership Corporate Invoiced DA'
#  'Better Health Centre - Gym Only (offline)'
#  'Better Health Corporate Partnership Plus Spa Invoiced'
#  'Better Health Partnership Community Funded 3 Months'
#  'Better Health Partnership Graduate' 'Better Swim Partnership Historic'
#  'Better Health Region Concessionary'
#  'Better Health Corporate UK + Elevate + Spa Invoiced'
#  'Better Health UK + Elevate + Spa offline'
#  'Better Health Centre - G&C (CBA/VP)'
#  'Lee Valley VeloPark Membership - Adult'
#  'Better Health Partnership Junior offline'
#  'Better Health UK Resident + Elevate' 'Better Golf 5 Day Senior FH'
#  'Better Health UK Community Funded' 'Better Health Region QEOP'
#  'Better Health Partnership Junior Plus Soft Play'
#  'Better Student Centre off peak CK' 'Better Health Partnership Funded MA'
#  'Better Health Centre GM02' 'Better Health Partnership Junior Funded'
#  'Better Elevate Partnership Concessionary'
#  'Lee Valley Partnership Health & Fitness Senior'
#  'Better Health UK Junior' 'Better Flex Adult Community Funded'
#  'Better Health Partnership Plus Spa DA'
#  'Better Health Partnership Junior Funded 6 month'
#  'Better Health Partnership Community Funded 6 Months'
#  'Better Health Centre Senior off peak' 'Better Golf 7 day FH'
#  'Better Health Junior Partnership Funded 3 month'
#  'Better Health Partnership Concessionary LAC Pathways'
#  'Better Student 4 month' 'Better Health Student 3 Months'
#  'Better Health Partnership KIC off peak'
#  'Better Health Centre Plus Racquets DA' 'Full Livery'
#  'Lee Valley Ice Training Concessionary'
#  'Better Health Corporate UK + Elevate + Spa' 'Better Health UK + Elevate'
#  'Better Health Partnership Plus Off Peak Spa' 'Better Health UK Priority'
#  'Better Health Community Network UK new' 'Better Health Partnership New'
#  'Better Health Centre - G,C&SS' 'Better Health Centre - G,S&C offline'
#  'Better Health UK (new)' 'Better Health Partnership 3 month'
#  'Better Health Corporate UK new' 'Lee Valley Corporate Partnership'
#  'Better Sports Adult Athletics Senior' 'Better Health UK Concessionary'
#  'Better Health Centre Concession anytime'
#  'Better Health Partnership Funded 6 weeks'
#  'Better Health Student 6 month offline CK02'
#  'Better Swim College Student' 'Better Health Corporate UK + Elevate'
#  'Better Health Region Funded 3 months' 'Better GP Referral 16 Weeks'
#  'Better Health Corporate Swim'
#  'Better Health Partnership Junior Funded 6 week'
#  'Better Health Corporate Invoiced Grenfell Adult' 'Better Golf 5 day FH'
#  'Better Health UK Community Funded 6 months'
#  'Better Health Corporate Invoiced Grenfell Junior'
#  'Better Health Corporate UK + Elevate Invoiced'
#  'Better Health Partnership Family Adult DA' 'Better Health Centre GM02 J'
#  'Better Health Centre G&C Res Plus Climb'
#  'Better Health Partnership Non Res Plus Spa DA']
# MembershipScope: ['Centre' 'Partnership' 'National' 'Other']
# DiscountType: ['No Discount' 'Senior' 'Corporate' 'Disability' 'Student' 'GSF'
#  'GP Referral' 'Concessionary' 'Carer']
# IsDiscounted: ['No' 'Yes']
# LengthOfStayInMonths: [ 70.  41.  72.  61.  25.  12.  11.  14.  44.  27. 163.  20.  92.  32.
#   28.  66.  21. 118. 136.  83.  52.  24.  34.  54.  35.   4.  15.  64.
#   62. 142.  73.  80.  18.  48.   7.   8. 129.   5.  38. 125. 134. 108.
#   81. 128. 131. 116.  58. 183. 126. 120. 115.  36.  29. 159. 117. 122.
#   55. 112. 119.  85.  37.  40. 114. 123.  95.  77.  31.  45.  39. 121.
#  110. 124.  89.  76.  96.  75.  74. 107. 189. 103. 109.  90. 137. 175.
#   19. 113.  65.  98.  99.  23.  97. 102. 105.  94.  13.  78. 111.  93.
#   91.  79. 187. 168.  87. 104.  86.  67. 140. 100. 188.  68.  88. 170.
#   49. 101. 194. 106.  26.  33. 176.  30. 162.  57. 141.  82.  16. 160.
#  182.  60.  69.  50.  42.  22.  53.  84.  56. 146.  71.  59.   2.  63.
#   10. 157.  46.  43.   6.  47. 151. 149.  51.  17. 135. 227.   9.   3.
#  156. 143. 130. 185. 133. 127. 204. 201. 235. 138. 158. 164. 196. 197.
#  145. 265. 241. 148. 132. 171. 180. 231. 179. 153. 161. 205. 139. 237.
#  214. 234. 219. 203. 287. 169. 259. 190. 147. 150. 172. 268. 152. 184.
#  155. 206. 213. 212. 192. 191. 166.   1. 228. 167. 202. 178. 217. 216.
#  174. 209. 225. 247. 193. 144. 220. 238. 165. 199. 271. 230. 186. 245.
#  294. 177.   0. 314. 218. 242. 173. 223. 154. 207. 198. 277. 256. 195.
#  211. 244. 336. 249. 252. 181. 210. 221. 302. 229. 306. 278. 240. 262.
#  289. 258. 208. 282. 304. 224. 255. 232. 239. 248. 273. 236. 200. 283.
#  251. 250. 290. 261. 233. 307.  -1. 222. 276. 342.  -5.  -8.  -9.  -2.
#   -7.  -3.]
# Persona: ['Community Carol' 'Family-focused Fiona' 'Pension Patty' 'Not Given'
#  'Nomadic Nick' 'Mansion Mike' 'Village Victor' 'Metropolitan Max'
#  'Starter-Home Steve' 'Budgeting Brenda' 'Downtown Danielle'
#  'Urban Ursula' 'Golden Age Gary' 'Suburban Sara' 'Conservative Chris'
#  'Rural Rachel']
# IMD10: [ 2.  4.  7.  8.  6. 10.  9.  1.  5.  3.]
# output_area_classification_supergroup: ['Cosmopolitans' 'Multicultural metropolitans' 'Urbanites' 'Suburbanites'
#  'Rural residents' 'Hard-pressed living' 'Ethnicity central'
#  'Constrained city dwellers']
# TerminationReason: ['membership_cancelled']
# UsageType: ['Gym' 'Fitness Class' 'Mixed' 'Other' 'Swim']
# VisitsPerMonth: [2.38562353e+00 3.37423887e+00 1.56515806e+00 ... 3.09191360e-01
#  3.90347656e+01 2.84933958e-02]

# %%
df.to_csv("Prepared Data.csv", index = False)
